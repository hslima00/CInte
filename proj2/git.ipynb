# %%
from cmath import inf
from turtle import title
from typing import Counter
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import seaborn as sns
import operator
import random

import numpy as np
from math import sqrt, sin, copysign

from deap import base
from deap import benchmarks
from deap import creator
from deap import tools

def front(self, n):
    return self.iloc[: , :n]

pd.DataFrame.front = front

no_cities = 10


df = pd.read_csv("CustDist_WHCentral.csv")
df_2 = pd.read_csv("CustOrd.csv")
df_3 = pd.read_csv("CustXY_WHCentral.csv")

df_dist = df.head(11)
df_dist = df_dist.front(12)               #For 10 cities

df_ord = df_2.head(11)                #For 10 cities
df_ord = df_ord.front(12)               #For 10 cities

df_xy = df_3.head(11)                #For 10 cities
df_xy = df_xy.front(12)               #For 10 cities


##Dataframe to np.arrays
dist = pd.DataFrame(df_dist).to_numpy()
dist = np.delete(dist,0,1)

order = pd.DataFrame(df_ord).to_numpy()
order = np.delete(order,0,1)

coord_xy = pd.DataFrame(df_xy).to_numpy()
coord_xy = np.delete(coord_xy,0,1)

creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()

IND_SIZE = 10 # 

toolbox.register("indices",random.sample, range(0,IND_SIZE), IND_SIZE)
toolbox.register("individual", tools.initIterate, creator.Individual, toolbox.indices)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("mutate", tools.mutFlipBit, indpb=0.05)
toolbox.register("mate", tools.cxOrdered)


def count_total_orders(order):
    sum_order = np.sum(order)
    return sum_order

def eval_Distances(individual):
    sum_distances = 0

    for i in range(0,no_cities):
        if(i == 0):
            sum_distances = dist[0][individual[0]+1]
        else:
            sum_distances = sum_distances+dist[individual[i-1]+1][individual[i]+1]

    sum_distances = sum_distances + dist[0][individual[no_cities-1]+1]
    return [sum_distances,]

toolbox.register("evaluate", eval_Distances)

def plot_values(best_ind_original):
    for cnt in range(10):
        index = best_ind_original[cnt]

        if(cnt == 0):
            x_values = [coord_xy[0][0], coord_xy[index][0]]
            y_values = [coord_xy[0][1], coord_xy[index][1]]
            prev_index = index
            plt.plot(x_values, y_values, 'bo', linestyle='--')
            plt.text(coord_xy[0][0]-1, coord_xy[0][1] - 6, '0')
            plt.text(coord_xy[index][0]-1, coord_xy[index][1] - 6, f'{index}')
        else:
            x_values = [coord_xy[prev_index][0], coord_xy[index][0]]
            y_values = [coord_xy[prev_index][1], coord_xy[index][1]]
            prev_index = index
            plt.plot(x_values, y_values, 'bo', linestyle='--')
            plt.text(coord_xy[index][0]-1, coord_xy[index][1] - 6, f'{index}')
        

        if(cnt == 9):
            x_values = [coord_xy[0][0], coord_xy[index][0]]
            y_values = [coord_xy[0][1], coord_xy[index][1]]
            plt.plot(x_values, y_values, 'bo', linestyle='--')

    plt.grid()
    plt.show()

def main():
    random.seed(64)
    pop = toolbox.population(n=200)

    CXPB, MUTPB = 0.70, 0.2
    
    print("Start of evolution")

    sum_order = count_total_orders(order)

    if(sum_order<1000):
        fitnesses = list(map(toolbox.evaluate, pop))
        for ind, fit in zip(pop, fitnesses):
            ind.fitness.values = fit

    print("  Evaluated %i individuals" % len(pop))

    # Extracting all the fitnesses of 
    fits = [ind.fitness.values[0] for ind in pop]


    # Variable keeping track of the number of generations
    g = 0

    std = inf

    arr_mean = []
    arr_min = []
    
    while g < 50 or std != 0:
        g = g + 1
        print("-- Generation %i --" % g)
        
        # Select the next generation individuals
        offspring = toolbox.select(pop, len(pop))
        # Clone the selected individuals
        offspring = list(map(toolbox.clone, offspring))

        for child1, child2 in zip(offspring[::2], offspring[1::2]):

            # cross two individuals with probability CXPB
            if random.random() < CXPB:

                toolbox.mate(child1, child2)

                # fitness values of the children
                # must be recalculated later
                del child1.fitness.values
                del child2.fitness.values

    
        # Evaluate the individuals with an invalid fitness
        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        fitnesses = map(toolbox.evaluate, invalid_ind)
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit
        
        print("  Evaluated %i individuals" % len(invalid_ind))
        
        # The population is entirely replaced by the offspring
        pop[:] = offspring
        
        # Gather all the fitnesses in one list and print the stats
        fits = [ind.fitness.values[0] for ind in pop]
        
        length = len(pop)
        mean = sum(fits) / length
        sum2 = sum(x*x for x in fits)
        std = abs(sum2 / length - mean**2)**0.5
        
        print("  Min %s" % min(fits))
        print("  Max %s" % max(fits))
        print("  Avg %s" % mean)
        print("  Std %s" % std)


        best_ind = tools.selBest(pop, 1)[0]
        best_ind_original = [x+1 for x in best_ind]

        print("Best individual in Generation %d %s, %s" % (g, best_ind_original, best_ind.fitness.values))

        arr_mean.append(mean)
        arr_min.append(min(fits))

    x_coordinate = [i+1 for i in range(len(arr_mean))]
    plt.plot(x_coordinate, arr_mean, label = "Average")
    plt.plot(x_coordinate, arr_min, label = "Min")
    plt.title("Min and Average Fitness over generations")
    plt.legend()
    plt.grid()
    plt.figure()
    plot_values(best_ind_original)



if __name__ == "__main__":
    main()
# Out:
# Start of evolution
#   Evaluated 200 individuals
# -- Generation 1 --
#   Evaluated 158 individuals
#   Min 394.0
#   Max 647.0
#   Avg 510.84
#   Std 43.57722340856524
# Best individual in Generation 1 [8, 7, 5, 6, 3, 9, 10, 4, 1, 2], (394.0,)
# -- Generation 2 --
#   Evaluated 134 individuals
#   Min 384.0
#   Max 596.0
#   Avg 484.68
#   Std 41.06966763926881
# Best individual in Generation 2 [8, 9, 3, 2, 1, 4, 10, 7, 5, 6], (384.0,)
# -- Generation 3 --
#   Evaluated 136 individuals
#   Min 374.0
#   Max 625.0
#   Avg 465.265
#   Std 45.19385771318951
# Best individual in Generation 3 [8, 5, 7, 4, 10, 6, 1, 2, 3, 9], (374.0,)
# -- Generation 4 --
#   Evaluated 152 individuals
#   Min 334.0
#   Max 580.0
#   Avg 463.935
#   Std 44.99867525827841
# Best individual in Generation 4 [6, 8, 5, 7, 4, 10, 1, 2, 9, 3], (334.0,)
# -- Generation 5 --
#   Evaluated 128 individuals
#   Min 343.0
#   Max 571.0
#   Avg 445.78
#   Std 43.07715868067475
# Best individual in Generation 5 [2, 1, 10, 3, 9, 6, 8, 5, 7, 4], (343.0,)
# -- Generation 6 --
#   Evaluated 144 individuals
#   Min 330.0
#   Max 580.0
#   Avg 434.41
#   Std 47.12623367085448
# Best individual in Generation 6 [6, 5, 8, 7, 4, 10, 1, 2, 3, 9], (330.0,)
# -- Generation 7 --
#   Evaluated 168 individuals
#   Min 317.0
#   Max 561.0
#   Avg 425.285
#   Std 50.165264626033604
# Best individual in Generation 7 [6, 8, 5, 7, 4, 10, 1, 2, 3, 9], (317.0,)
# -- Generation 8 --
#   Evaluated 142 individuals
#   Min 317.0
#   Max 563.0
#   Avg 408.695
#   Std 50.01241820788125
# Best individual in Generation 8 [6, 8, 5, 7, 4, 10, 1, 2, 3, 9], (317.0,)
# -- Generation 9 --
#   Evaluated 142 individuals
#   Min 306.0
#   Max 568.0
#   Avg 399.025
#   Std 48.58142005952524
# Best individual in Generation 9 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 10 --
#   Evaluated 128 individuals
#   Min 306.0
#   Max 537.0
#   Avg 390.605
#   Std 53.45595359733071
# Best individual in Generation 10 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 11 --
#   Evaluated 154 individuals
#   Min 306.0
#   Max 527.0
#   Avg 385.09
#   Std 52.843939103742194
# Best individual in Generation 11 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 12 --
#   Evaluated 128 individuals
#   Min 306.0
#   Max 556.0
#   Avg 372.1
#   Std 50.62696909750767
# Best individual in Generation 12 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 13 --
#   Evaluated 152 individuals
#   Min 306.0
#   Max 530.0
#   Avg 365.585
#   Std 49.69942429244025
# Best individual in Generation 13 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 14 --
#   Evaluated 146 individuals
#   Min 306.0
#   Max 495.0
#   Avg 357.865
#   Std 46.49372834049761
# Best individual in Generation 14 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 15 --
#   Evaluated 136 individuals
#   Min 306.0
#   Max 468.0
#   Avg 350.8
#   Std 51.75693190288605
# Best individual in Generation 15 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 16 --
#   Evaluated 138 individuals
#   Min 306.0
#   Max 491.0
#   Avg 336.825
#   Std 47.77273673341328
# Best individual in Generation 16 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 17 --
#   Evaluated 156 individuals
#   Min 306.0
#   Max 468.0
#   Avg 317.775
#   Std 34.47541696629675
# Best individual in Generation 17 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 18 --
#   Evaluated 136 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 18 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 19 --
#   Evaluated 128 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 19 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 20 --
#   Evaluated 134 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 20 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 21 --
#   Evaluated 134 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 21 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 22 --
#   Evaluated 138 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 22 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 23 --
#   Evaluated 140 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 23 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 24 --
#   Evaluated 144 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 24 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 25 --
#   Evaluated 136 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 25 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 26 --
#   Evaluated 162 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 26 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 27 --
#   Evaluated 134 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 27 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 28 --
#   Evaluated 154 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 28 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 29 --
#   Evaluated 134 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 29 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 30 --
#   Evaluated 150 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 30 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 31 --
#   Evaluated 128 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 31 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 32 --
#   Evaluated 130 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 32 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 33 --
#   Evaluated 146 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 33 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 34 --
#   Evaluated 150 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 34 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 35 --
#   Evaluated 118 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 35 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 36 --
#   Evaluated 126 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 36 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 37 --
#   Evaluated 120 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 37 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 38 --
#   Evaluated 142 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 38 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 39 --
#   Evaluated 154 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 39 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 40 --
#   Evaluated 142 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 40 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 41 --
#   Evaluated 158 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 41 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 42 --
#   Evaluated 136 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 42 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 43 --
#   Evaluated 154 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 43 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 44 --
#   Evaluated 146 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 44 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 45 --
#   Evaluated 140 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 45 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 46 --
#   Evaluated 142 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 46 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 47 --
#   Evaluated 126 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 47 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 48 --
#   Evaluated 150 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 48 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 49 --
#   Evaluated 134 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 49 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
# -- Generation 50 --
#   Evaluated 152 individuals
#   Min 306.0
#   Max 306.0
#   Avg 306.0
#   Std 0.0
# Best individual in Generation 50 [10, 1, 2, 3, 9, 6, 8, 5, 7, 4], (306.0,)
